# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
### Numpy

# %%
np.array("Qasim")

# %%
small_list = [1, 2, 3, 4]
small_array = np.array([1,2,3,4])

# %%
longlist = small_list + small_list
longlist
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
array_result = small_array * small_array
array_result
# Out:
# array([ 1,  4,  9, 16])

# %%
#2D array in numpy
height_weight = np.array([[1.8, 1.9, 1.7], # heights
                           [70, 80, 90]]) # weights1

# %%
np.random.normal(1.75, 0.20, 5000)
# Out:
# array([1.70787792, 1.53437028, 1.957462  , ..., 1.88590423, 1.8266834 ,
#        1.71607226])

# %%
#MATPLOTLIB 

# LINE PLOT 

year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

plt.plot(year, pop)
# plt.show()

# %%
plt.scatter(year, pop)

# %% [markdown]
# ### Histogram
#
# bin actually divides the intervals based on the max and min values

# %%
values = [0, 0.6, 1.4, 1.6, 2.2, 2.5, 2.6, 3.2, 3.5, 3.9, 4.2, 6]
plt.hist(values, bins=5)
plt.show()

# %%
decades = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
populations = [2.5, 2.7, 3, 3.3, 3.6, 4.2, 4.5]

plt.plot(decades, populations, color='purple', marker='o')
plt.xlabel('Decades')
plt.ylabel('Population')
plt.title('World Population Over Time')
plt.yticks([0, 2, 4, 6, 8, 10], ['0', '2B', '4B', '6B', '8B', '10B'])
plt.show()
